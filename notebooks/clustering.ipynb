# %% [markdown]
# # Setup

# %%
# %matplotlib inline
# %cd ..
import matplotlib.pyplot as plt
import numpy as np

from models.kmeans import KMeans
# Out:
# /home/joaopaulo/Documents/repos/ml

# %% [markdown]
# # Example 1 - Random Data

# %%
from sklearn.datasets import make_blobs
X, y = make_blobs(n_samples=300,
                  centers=4,
                  cluster_std=0.60,
                  random_state=0)

plt.scatter(X[:, 0], X[:, 1], s=50, cmap='viridis')
# Out:
# /tmp/ipykernel_14075/1728981599.py:7: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[:, 0], X[:, 1], s=50, cmap='viridis')

# %%
km = KMeans(k=4)
km.fit(X)

# %%
km.clusters.shape
# Out:
# (4, 2)

# %%
plt.scatter(X[:, 0], X[:, 1], c=km.centroids, s=50, cmap='viridis')
plt.scatter(km.clusters[:, 0], km.clusters[:, 1], marker='x', c='red')

# %% [markdown]
# # Example 2 - MNIST

# %%
from sklearn.datasets import load_digits
digits = load_digits()

# %%
km = KMeans(k=10)
km.fit(digits.data)

# %%
fig, ax = plt.subplots(2, 5)
ax = ax.flatten()
for i in range(10):
    plottable_image = np.reshape(km.clusters[i], (8, 8))
    ax[i].imshow(plottable_image, cmap='gray_r')
