# %% [markdown]
# # Setup

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

from models.logistic_regression import LogisticRegression
from models.perceptron import Perceptron
from models.gda import GDA
from models.knn import KNN

# %% [markdown]
# # Example - Random Blobs

# %%
from sklearn.datasets import make_blobs

X, y = make_blobs(n_samples=500,
                  centers=2,
                  cluster_std=0.60,
                  random_state=0)

plt.scatter(X[:, 0], X[:, 1], s=50, cmap='viridis')

# %% [markdown]
# ## K-Nearest Neighbors

# %%
knn = KNN()
knn.fit(X, y)
h_x = knn.predict(X)

# %%
plt.scatter(X[:, 0], X[:, 1], c=h_x, s=50, cmap='viridis')

# %% [markdown]
# ## Perceptron

# %%
per = Perceptron()
per.fit(X, y)
h_x = per.predict(X)

# %%
plt.scatter(X[:, 0], X[:, 1], c=h_x, s=50, cmap='viridis')

# %% [markdown]
# ## Logistic Regression

# %%
log = LogisticRegression()
log.fit(X, y)
h_x = log.predict(X)
# Out:
# c:\Users\joaop\Documents\Repos\ml-scratch\notebooks\util.py:6: RuntimeWarning: overflow encountered in exp
#   return 1.0 / (1 + np.exp(-z))

# %%
plt.scatter(X[:, 0], X[:, 1], c=h_x, s=50, cmap='viridis')

# %% [markdown]
# ## Gaussian Discriminant Analysis

# %%
gda = GDA()
gda.fit(X, y)
h_x = gda.predict(X)

# %%
plt.scatter(X[:, 0], X[:, 1], c=h_x, s=50, cmap='viridis')
