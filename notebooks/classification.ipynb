# %% [markdown]
# # Setup

# %%
# %matplotlib inline
# %cd ..
import matplotlib.pyplot as plt
import numpy as np

from sklearn.datasets import make_blobs

from models.logistic_regression import LogisticRegression
from models.perceptron import Perceptron
from models.gda import GDA
from models.knn import KNN
# Out:
# /home/joaopaulo/Documents/repos/ml

# %% [markdown]
# # Example - Random Blobs

# %%
X, y = make_blobs(n_samples=500,
                  centers=2,
                  cluster_std=0.60,
                  random_state=0)

plt.scatter(X[:, 0], X[:, 1], s=50)

# %% [markdown]
# ## K-Nearest Neighbors

# %%
knn = KNN()
knn.fit(X, y)
h_x = knn.predict(X)

# %%
plt.scatter(X[:, 0], X[:, 1], c=h_x, s=50, cmap='viridis')

# %% [markdown]
# ## Perceptron

# %%
per = Perceptron()
per.fit(X, y, verbose=True)
h_x = per.predict(X)
# Out:
# Loss on iteration 0: 250
# Loss on iteration 100: 3

# %%
plt.scatter(X[:, 0], X[:, 1], c=h_x, s=50, cmap='viridis')

# %% [markdown]
# ## Logistic Regression

# %%
log = LogisticRegression()
log.fit(X, y)
h_x = log.predict(X)
# Out:
# /home/joaopaulo/Documents/repos/ml/models/logistic_regression.py:97: RuntimeWarning: overflow encountered in exp
#   return 1.0 / (1 + np.exp(-z))

# %%
plt.scatter(X[:, 0], X[:, 1], c=h_x, s=50, cmap='viridis')

# %% [markdown]
# ## Gaussian Discriminant Analysis

# %%
gda = GDA()
gda.fit(X, y)
h_x = gda.predict(X)

# %%
plt.scatter(X[:, 0], X[:, 1], c=h_x, s=50, cmap='viridis')
